# %%
import pandas as pd
import matplotlib.pyplot as plt
a = pd.read_csv("/content/House_prediction.csv")
g = a.groupby('city').mean().area.plot(kind='bar')#for area

t = a.groupby('city').mean().rooms
f = a.groupby('city').mean().bathroom
g.plot()
# Out:
# []

# %%
t
# Out:
# city
# Belo Horizonte    3.020668
# Campinas          2.355217
# Porto Alegre      2.140821
# Rio de Janeiro    2.243837
# São Paulo         2.558859
# Name: rooms, dtype: float64

# %%
f
# Out:
# city
# Belo Horizonte    2.402226
# Campinas          1.960141
# Porto Alegre      1.725901
# Rio de Janeiro    1.756163
# São Paulo         2.467641
# Name: bathroom, dtype: float64

# %%
import seaborn as sb
dataplot = sb.heatmap(a.corr(),cmap="YlGnBu", annot=True)
plt.show()
